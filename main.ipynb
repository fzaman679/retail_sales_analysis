# %% [markdown]
# #### Folder Names

# %%
import sys, os
current_folder_location = os.getcwd()
data_folder = current_folder_location + '\\data\\'
raw_data_folder = data_folder + 'raw_data\\'
clean_data_folder = data_folder + 'clean_data\\'

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import calendar

from Utils.functions import *

# %%
sales = pd.read_csv(raw_data_folder + 'sales.csv')
customers = pd.read_csv(raw_data_folder +'customers.csv')
orders = pd.read_csv(raw_data_folder + 'orders.csv')
products = pd.read_csv(raw_data_folder + 'products.csv')

# %%
sales
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0            0         1         218             106         2          212
# 1            1         1         481             118         1          118
# 2            2         1           2              96         3          288
# 3            3         1        1002             106         2          212
# 4            4         1         691             113         3          339
# ...        ...       ...         ...             ...       ...          ...
# 4995      4995       998         321             109         2          218
# 4996      4996       998         251              95         3          285
# 4997      4997       999         872             113         1          113
# 4998      4998       999         998             106         2          212
# 4999      4999       999        1105             115         1          115
#
# [5000 rows x 6 columns]

# %%
customers
# Out:
#      customer_id        customer_name       gender  age  \
# 0              1        Leanna Busson       Female   30
# 1              2  Zabrina Harrowsmith  Genderfluid   69
# 2              3      Shina Dullaghan   Polygender   59
# 3              4        Hewet McVitie     Bigender   67
# 4              5       Rubia Ashleigh   Polygender   30
# ..           ...                  ...          ...  ...
# 995          996       Elvira Sarfati      Agender   59
# 996          997       Dickie Grushin   Non-binary   30
# 997          998       Rebecka Fabler   Polygender   32
# 998          999       Carita Vynarde   Polygender   30
# 999         1000     Mandel Fairbanks         Male   71
#
#                        home_address  zip_code                city  \
# 0    8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# 1        8327 Kirlin SummitApt. 461      8223     New Zacharyfort
# 2         269 Gemma SummitSuite 109      5661            Aliburgh
# ...

# %%
customers = get_clean_customers(customers)
customers
# Out:
#      customer_id        customer_name       gender  age  \
# 0              1        Leanna Busson       Female   30
# 1              2  Zabrina Harrowsmith  Genderfluid   69
# 2              3      Shina Dullaghan   Polygender   59
# 3              4        Hewet McVitie     Bigender   67
# 4              5       Rubia Ashleigh   Polygender   30
# ..           ...                  ...          ...  ...
# 995          996       Elvira Sarfati      Agender   59
# 996          997       Dickie Grushin   Non-binary   30
# 997          998       Rebecka Fabler   Polygender   32
# 998          999       Carita Vynarde   Polygender   30
# 999         1000     Mandel Fairbanks         Male   71
#
#                        home_address  zip_code                city  \
# 0    8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# 1        8327 Kirlin SummitApt. 461      8223     New Zacharyfort
# 2         269 Gemma SummitSuite 109      5661            Aliburgh
# ...

# %%
orders = get_clean_orders_df(df=orders)
orders
# Out:
#      order_id  customer_id  payment order_date delivery_date Delivery_time  \
# 0           1           64    30811 2021-08-30    2021-09-24       25 days
# 1           2          473    50490 2021-02-03    2021-02-13       10 days
# 2           3          774    46763 2021-10-08    2021-11-03       26 days
# 3           4          433    39782 2021-05-06    2021-05-19       13 days
# 4           5          441    14719 2021-03-23    2021-03-24        1 days
# ..        ...          ...      ...        ...           ...           ...
# 995       996          345    37843 2021-01-13    2021-02-02       20 days
# 996       997          346    53831 2021-01-18    2021-01-31       13 days
# 997       998          407    53308 2021-05-05    2021-05-21       16 days
# 998       999          428    31643 2021-06-15    2021-07-12       27 days
# 999      1000          896    27836 2021-04-07    2021-04-24       17 days
#
#      Year  Month  Day
# 0    2021      8   30
# ...

# %%
products
# Out:
#       product_ID product_type       product_name size  colour  price  \
# 0              0        Shirt       Oxford Cloth   XS     red    114
# 1              1        Shirt       Oxford Cloth    S     red    114
# 2              2        Shirt       Oxford Cloth    M     red    114
# 3              3        Shirt       Oxford Cloth    L     red    114
# 4              4        Shirt       Oxford Cloth   XL     red    114
# ...          ...          ...                ...  ...     ...    ...
# 1255        1255     Trousers  Tracksuit Bottoms   XS  violet     91
# 1256        1256     Trousers  Tracksuit Bottoms    S  violet     91
# 1257        1257     Trousers  Tracksuit Bottoms    M  violet     91
# 1258        1258     Trousers  Tracksuit Bottoms    L  violet     91
# 1259        1259     Trousers  Tracksuit Bottoms   XL  violet     91
#
#       quantity                                        description
# 0           66       A red coloured, XS sized, Oxford Cloth Shirt
# ...

# %% [markdown]
# ### Sales by Product ID, What Product has generated highest revenue?

# %%
top_rev_products = get_top_10_products_by_rev(df=sales, df_products=products)

# %%
graph_top_10_products_by_rev(df=top_rev_products)
# Out:
# Text(0.5, 1.0, 'Total Revenue Per Product')

# %% [markdown]
# ## Top 20 Customers

# %%
top_20_customers = get_20_best_customers(df_sales = sales, df_orders=orders, df_customers=customers)
top_20_customers
# Out:
#      customer_id  total_price         customer_name  age  \
# 449          282         7632          Wren Helgass   59
# 265          571         6640        Kristofor Roos   22
# 206          664         6341         Dannie Fidler   32
# 193          683         5657      Esteban Hensmans   45
# 495          206         5581         Crin Johnikin   66
# 269          566         5435       Melissa Partkya   23
# 403          348         5119       Thorny Nornable   76
# 109          813         4969         Saul Franklyn   62
# 328          465         4807    Mallory Castellani   38
# 169          727         4428       Herschel Verdey   26
# 1            998         4415        Rebecka Fabler   32
# 532          129         4399  Beatrisa Winterscale   68
# 547          107         4385      Sandy Yushachkov   35
# 165          732         4240          Gorden Seago   80
# 259          581         4216        Fabian Gostage   40
# ...

# %%
graph_top_20_customers(df=top_20_customers)
# Out:
# Text(0.5, 1.0, 'Top 20 Customers')

# %% [markdown]
# ## Delivery for top 20 customers

# %%
delivery_time_for_top_20_customers= get_delivery_time_for_best_customers(df_orders = orders, top_20_customers = top_20_customers)
delivery_time_for_top_20_customers
# Out:
#             Delivery_time
#                      mean min max
# customer_id
# 107                  14.0  11  20
# 129                  13.0   7  17
# 206                   7.0   1  16
# 244                  13.0   5  20
# 282                   8.0   1  21
# 348                  18.0  13  24
# 382                  16.0  14  19
# 465                  14.0   4  22
# 566                  11.0   2  20
# 571                  17.0   9  27
# 581                   9.0   2  21
# 623                  14.0   6  26
# 643                   8.0   3  11
# 664                  21.0  17  24
# 683                  17.0   2  25
# 727                  22.0  17  27
# 732                  16.0   9  21
# 813                  19.0  14  23
# 908                  18.0  12  21
# 998                  13.0   3  23

# %% [markdown]
# ## Sales by Month

# %%
sales_by_month = get_n_of_orders_by_month(df=orders)
sales_by_month
# Out:
#   Month  n of orders
# 0   Jan          109
# 1   Feb           94
# 2   Mar          118
# 3   Apr          101
# 4   May           84
# 5   Jun          103
# 6   Jul          105
# 7   Aug          107
# 8   Sep           98
# 9   Oct           81

# %%
graph_n_orders_per_month(df=sales_by_month)
# Out:
# Text(0.5, 1.0, 'Number of Orders per Month')
